# %%
# %load_ext autotime
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 200 µs (started: 2023-02-28 12:59:01 -05:00)

# %% [markdown]
# ### Imports

# %%
# import numpy as np
import matplotlib.pyplot as plt  # required for plotting

import json
import pennylane as qml
import pennylane.numpy as np

import jax
import networkx as nx

from functools import partial

from pennylane.templates import ApproxTimeEvolution

from collections import Counter
import math
import importlib
import pickle
import os


from scipy.spatial.distance import jensenshannon
# Out:
# time: 366 µs (started: 2023-02-28 12:59:01 -05:00)

# %%
# check we have the right version of pennylane
# note that pennylane-braket is only compatible with pennylane version 0.27.0
# but we can use the latest version of pennylane for other things
qml.version()
# Out:
# '0.27.0'
# time: 1.04 ms (started: 2023-02-28 12:59:01 -05:00)

# %%
import utils
utils = importlib.reload(utils)
from utils import *
# Out:
# time: 826 µs (started: 2023-02-28 12:59:01 -05:00)

# %%
import sys
# check using the right virtual environment
sys.prefix
# Out:
# '/Users/yan/Repositories/qhack23_rydberg_graph/venv'
# time: 1.08 ms (started: 2023-02-28 12:59:01 -05:00)

# %% [markdown]
# ## Construct hamiltonian demo (simple graph example)

# %% [markdown]
# ### Graph construction

# %%
graphA_nodes = np.array([[0., 0.],[0., 1.], [np.sqrt(3)/2, 0.5], [np.sqrt(3)/2 + 1., 0.5], 
                          [np.sqrt(3) + 1., 0.], [np.sqrt(3) + 1., 1.]])
graphB_nodes = np.array([[0., 0.],[0., 1.], [1., 0.], [1, 1], 
                          [2., 0.], [2., 1.]])                          
graphs_nodes = [graphA_nodes, graphB_nodes] 

# Construct graph specifications from geometric nodes
graphs_pos = []
graphs_geometric = []
for graph_nodes in graphs_nodes:
    pos = dict(zip(range(len(graph_nodes)), graph_nodes))
    geometric = [(i, dict(zip(['pos'], [pos[i]]))) for i in range(len(graph_nodes))]
    graphs_pos.append(pos)
    graphs_geometric.append(geometric)

graphA_nodes_geometric = graphs_geometric[0]
graphA_nodes_pos = graphs_pos[0]
# graphA_nodes_pos = dict(zip(range(len(graphA_nodes)), graphA_nodes))
# graphA_nodes_geometric = [(i, dict(zip(['pos'], [graphA_nodes_pos[i]]))) for i in range(len(graphA_nodes))]
# print(graphA_nodes_geometric)
# Out:
# time: 685 µs (started: 2023-02-28 12:59:01 -05:00)

# %%
#@title Construct graph from geometric nodes
def construct_graph(graph_nodes_geometric, radius=3.1):
    G = nx.Graph()
    G.add_nodes_from(graph_nodes_geometric)
    # nx.geometric_edges(G, radius=1)

    for edge in nx.geometric_edges(G, radius):
        # print(edge)
        G.add_edge(*edge)
    return G
G = construct_graph(graphA_nodes_geometric)
nx.draw(G, with_labels=True, pos=graphA_nodes_pos, node_size=600)
# Out:
# time: 64.3 ms (started: 2023-02-28 12:59:01 -05:00)

# %%
Gs = [construct_graph(graph_nodes_geometric) for graph_nodes_geometric in graphs_geometric]
# Out:
# time: 477 µs (started: 2023-02-28 12:59:01 -05:00)

# %%
def build_hamiltonian(G, omega, delta):
    """
    Builds the approximated Hamiltonian for the given graph.
    Args:
        G (nx.Graph): Graph to build the Hamiltonian for.
        omega (float): Frequency of the oscillator.
        delta (float): Detuning of the oscillator.
    Returns:
        qml.Hamiltonian: Hamiltonian for the given graph.
    """    
    obs = []
    coeffs = []

    V_r = np.sqrt(omega**2 + delta**2)  # rad / sec # Rydberg interaction strength converted from 

    for node in G.nodes(): # construct onsite terms
        coeffs.extend([omega / 2., - delta / 2.])
        obs.extend([qml.PauliX(node), qml.PauliZ(node)])
    for edge in G.edges():
        coeffs.extend([V_r / 4., V_r / 2., V_r / 2.]) 
        obs.extend([qml.PauliZ(edge[0]) @ qml.PauliZ(edge[1]),
                            qml.PauliZ(edge[0]),
                            qml.PauliZ(edge[1])])
    return qml.Hamiltonian(coeffs, obs)


# units for hbar = 1
omega = 1e6  # rad / sec
delta = 0.7 * omega

hamiltonian_rydberg = build_hamiltonian(G, omega, delta)
print(hamiltonian_rydberg)
# Out:
#   (-350000.0) [Z0]
# + (-350000.0) [Z1]
# + (-350000.0) [Z2]
# + (-350000.0) [Z3]
# + (-350000.0) [Z4]
# + (-350000.0) [Z5]
# + (500000.0) [X0]
# + (500000.0) [X1]
# + (500000.0) [X2]
# + (500000.0) [X3]
# + (500000.0) [X4]
# + (500000.0) [X5]
# + (610327.7807866852) [Z0]
# + (610327.7807866852) [Z1]
# + (610327.7807866852) [Z0]
# + (610327.7807866852) [Z2]
# + (610327.7807866852) [Z0]
# + (610327.7807866852) [Z3]
# + (610327.7807866852) [Z0]
# + (610327.7807866852) [Z4]
# + (610327.7807866852) [Z0]
# + (610327.7807866852) [Z5]
# + (610327.7807866852) [Z1]
# + (610327.7807866852) [Z2]
# + (610327.7807866852) [Z1]
# + (610327.7807866852) [Z3]
# + (610327.7807866852) [Z1]
# + (610327.7807866852) [Z4]
# + (610327.7807866852) [Z1]
# + (610327.7807866852) [Z5]
# + (610327.7807866852) [Z2]
# + (610327.7807866852) [Z3]
# + (610327.7807866852) [Z2]
# + (610327.7807866852) [Z4]
# + (610327.7807866852) [Z2]
# + (610327.7807866852) [Z5]
# + (610327.7807866852) [Z3]
# + (610327.7807866852) [Z4]
# + (610327.7807866852) [Z3]
# + (610327.7807866852) [Z5]
# + (610327.7807866852) [Z4]
# + (610327.7807866852) [Z5]
# + (305163.8903933426) [Z0 Z1]
# + (305163.8903933426) [Z0 Z2]
# + (305163.8903933426) [Z0 Z3]
# + (305163.8903933426) [Z0 Z4]
# + (305163.8903933426) [Z0 Z5]
# + (305163.8903933426) [Z1 Z2]
# + (305163.8903933426) [Z1 Z3]
# + (305163.8903933426) [Z1 Z4]
# + (305163.8903933426) [Z1 Z5]
# + (305163.8903933426) [Z2 Z3]
# + (305163.8903933426) [Z2 Z4]
# + (305163.8903933426) [Z2 Z5]
# + (305163.8903933426) [Z3 Z4]
# + (305163.8903933426) [Z3 Z5]
# + (305163.8903933426) [Z4 Z5]
# time: 1.4 ms (started: 2023-02-28 12:59:01 -05:00)

# %%
n_wires = len(G.nodes())
wires = range(n_wires)
shots = 10

dev = qml.device('default.qubit', wires=n_wires, shots=shots)


@qml.qnode(dev)
def circuit(time):
    ApproxTimeEvolution(hamiltonian_rydberg, time, 1)
    return qml.counts()
# Out:
# time: 1.27 ms (started: 2023-02-28 12:59:01 -05:00)

# %%
counts_results = circuit(1)
print(counts_results)
# Out:
# {'000000': 9, '000001': 1}
# time: 18.2 ms (started: 2023-02-28 12:59:01 -05:00)

# %%
get_counts_summed_probabilities(counts_results, shots)
# Out:
# array([0.9, 0.1, 0. , 0. , 0. , 0. , 0. ])
# time: 1.26 ms (started: 2023-02-28 12:59:01 -05:00)

# %% [markdown]
# ### run simulations for different time steps

# %%
### run the simulation for all graphs

# build hamiltonians for all
Gs = [construct_graph(graph_nodes_geometric) for graph_nodes_geometric in graphs_geometric]
# units for hbar = 1
omega = np.pi * 1e6  # rad / sec
delta = 0.7 * omega
hamiltonians = []
for graph in Gs:  
    hamiltonian_rydberg = build_hamiltonian(graph, omega, delta)
    hamiltonians.append(hamiltonian_rydberg)
# Out:
# time: 2.22 ms (started: 2023-02-28 12:59:01 -05:00)

# %%
n_wires = len(Gs[0].nodes())
# n_wires = len(n_nodes)
wires = range(n_wires)
shots = 1000

dev = qml.device('default.qubit', wires=n_wires, shots=shots)


@qml.qnode(dev)
def circuit(time, hamiltonian, n_trotter_steps=100):
    ApproxTimeEvolution(hamiltonian, time, n_trotter_steps)
    return qml.counts()
# Out:
# time: 1.31 ms (started: 2023-02-28 12:59:01 -05:00)

# %%
t_range = np.linspace(1e-8, 5.*1e-6, 100)
my_nodesB = [0, 1, 4, 5]
n_prob_list = []
n_expectationB_list = []
n_expectationC_list = []

results = []
# run simulation for different drive durations
for t_max in t_range:
    counts_results_graphs = []
    for hamiltonian in hamiltonians:
        n_trotter_steps = math.floor(t_max * 1e6) * 500 + 1
        # print(n_trotter_steps)
        counts_results = circuit(t_max, hamiltonian, n_trotter_steps)
        # print(counts_results)
        counts_results_graphs.append(counts_results)    
    results.append(counts_results_graphs)
# Out:
# time: 13min 29s (started: 2023-02-28 12:59:01 -05:00)

# %%
filename = 'demo_results_pennylane_local.p'

if not os.path.isdir('results_QEK/'):
    os.mkdir('results_QEK/')
with open("results_QEK/"+filename, 'wb') as f:
    f.write(pickle.dumps(results))
# Out:
# time: 11.5 ms (started: 2023-02-28 13:25:58 -05:00)

# %%
kernel_counts_fn = partial(outcome_counts, shots=shots)
kernels = []
for t_max, counts_graph in zip(t_range, results): # loop over different drive durations
    # counts_graph = [get_counts(result_graph) for result_graph in results_graph] # get state counts from simulator result
    # counts_graph = [get_counts(result) for result in results] # get state counts from simulator result
    kernel_t = compute_kernel(counts_graph, kernel_counts_fn) # compute kernel matrix
    kernels.append(kernel_t)
kernels = np.stack(kernels)
# Out:
# time: 5.92 ms (started: 2023-02-28 13:25:58 -05:00)

# %%
fig, axes = plt.subplots(1, 1, figsize=(12, 7))
axes.plot(t_range, (- np.log(kernels[:, 0, 1]))**2, label='kernel')
axes.set_xlabel('t')
axes.set_ylabel(r'Jensen-Shannon divergence $JS(P1, P2)$')
# Out:
# Text(0, 0.5, 'Jensen-Shannon divergence $JS(P1, P2)$')
# time: 156 ms (started: 2023-02-28 13:25:58 -05:00)

# %%
outcome_fn = partial(get_expectations_nodes, shots=shots, averaged_nodes=my_nodesB)
outcomes = []
for t_max, counts_graph in zip(t_range, results): # loop over different drive durations
    # counts_graph = [get_counts(result_graph) for result_graph in results_graph] # get state counts from simulator result
    outcomes_t = compute_outcomes(counts_graph, outcome_fn) # compute kernel matrix
    # print(outcomes_t.shape)
    outcomes.append(outcomes_t)
outcomes = np.stack(outcomes)
# Out:
# time: 6.21 ms (started: 2023-02-28 13:25:59 -05:00)

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 7), sharex=True)
y_labels = [r'$\langle n_B \rangle$', r'$\langle n_C \rangle$']
labels = ['B', 'C']
colors = ['r', 'b']
labels_graph = ['A', 'B']
for i, ylabel in enumerate(y_labels):
    ax = axes[i]
    for j in range(2):
        ax.plot(t_range, outcomes[:, j, i], '.-', label=f"graph {labels_graph[j]}", color=colors[j])
    ax.set_ylabel(ylabel)
    ax.legend()

plt.xlabel('Drive duration [s]')
# plt.legend()
# plt.ylabel(r'$\langle n \rangle$')
# Out:
# Text(0.5, 0, 'Drive duration [s]')
# time: 163 ms (started: 2023-02-28 13:25:59 -05:00)

# %%
t_list = [0.1e-6, 0.25e-6, 0.57e-6, 0.924e-6, 1.04e-6, 1.2e-6, 2.5e-6]
barWidth = 0.25
br1 = np.arange(len(graphA_nodes)+1)
br2 = [x + barWidth for x in br1]
bars = [br1, br2]
colors = ['r', 'b']
labels = ['graph A', 'graph B']
# plot the probability distribution for different drive durations as a function of summed states
fig, axes = plt.subplots(len(t_list), 1, figsize=(5, 4 * len(t_list)), sharex=True)
for t, ax in zip(t_list, axes):
    # idx = np.where(t_range == t)[0][0] # get index of t
    idx = np.argmin(np.abs(t_range - t))
    probabilities = []
    
    for i in range(2):
        counts_graph = results[idx][i]
        p = get_counts_summed_probabilities(counts_graph, shots=shots)
        probabilities.append(p)
        # print(p)

        ax.bar(bars[i], p, label=labels[i], width=barWidth, color=colors[i])
        # ax.set_ylim(0, 1)
        ax.set_ylabel("Probability")
        ax.set_xlabel(r"Summed states $\sum_i n_i$")
        ax.legend()
        ax.set_title('t = {:.2e}'.format(t_range[idx]))
    # ax.set_title('t = {:.2e}'.format(t))
# Out:
# time: 597 ms (started: 2023-02-28 13:25:59 -05:00)

# %% [markdown]
# ### run simulations for different time steps on SV1

# %%
### run the simulation for all graphs

# build hamiltonians for all
Gs = [construct_graph(graph_nodes_geometric) for graph_nodes_geometric in graphs_geometric]
# units for hbar = 1
omega = np.pi * 1e6  # rad / sec
delta = 0.7 * omega
hamiltonians = []
for graph in Gs:  
    hamiltonian_rydberg = build_hamiltonian(graph, omega, delta)
    hamiltonians.append(hamiltonian_rydberg)
# Out:
# time: 2.05 ms (started: 2023-02-28 13:25:59 -05:00)

# %%
my_bucket = "amazon-braket-us-west-1-880812766447"  # the name of the bucket, keep the 'amazon-braket-' prefix and then include the bucket name
my_prefix = "QEK_sv1_demo"  # the name of the folder in the bucket
s3_folder = (my_bucket, my_prefix)

device_arn = "arn:aws:braket:::device/quantum-simulator/amazon/sv1"
# Out:
# time: 253 µs (started: 2023-02-28 13:26:00 -05:00)

# %%
n_wires = len(Gs[0].nodes())
# n_wires = len(n_nodes)
wires = range(n_wires)
shots = 1000

# dev = qml.device('default.qubit', wires=n_wires, shots=shots)
dev_remote = qml.device(
    "braket.aws.qubit",
    device_arn=device_arn,
    wires=n_wires,
    s3_destination_folder=s3_folder,
    shots=shots,
    parallel=True,
)


@qml.qnode(dev_remote)
def circuit(time, hamiltonian, n_trotter_steps=100):
    ApproxTimeEvolution(hamiltonian, time, n_trotter_steps)
    return qml.probs(wires=wires)
# Out:
# time: 1.28 s (started: 2023-02-28 13:26:00 -05:00)

# %%
my_probs = circuit(1e-6, hamiltonians[0], 5)
# Out:
# time: 4.2 s (started: 2023-02-28 13:26:01 -05:00)

# %%
t_range = np.linspace(1e-8, 5.*1e-6, 100)
my_nodesB = [0, 1, 4, 5]
n_prob_list = []
n_expectationB_list = []
n_expectationC_list = []

results = []
# run simulation for different drive durations
for t_max in t_range:
    counts_results_graphs = []
    for hamiltonian in hamiltonians:
        n_trotter_steps = math.floor(t_max * 1e6) * 500 + 1
        # print(n_trotter_steps)
        counts_results = circuit(t_max, hamiltonian, n_trotter_steps)
        # print(counts_results)
        counts_results_graphs.append(counts_results)    
    results.append(counts_results_graphs)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[57], line 14
#      12 n_trotter_steps = math.floor(t_max * 1e6) * 500 + 1
#      13 # print(n_trotter_steps)
# ---> 14 counts_results = circuit(t_max, hamiltonian, n_trotter_steps)
#      15 # print(counts_results)
#      16 counts_results_graphs.append(counts_results)
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/pennylane/qnode.py:665, in QNode.__call__(self, *args, **kwargs)
#     661     self._update_original_device()
#     663     return res
# --> 665 res = qml.execute(
#     666     [self.tape],
#     667     device=self.device,
#     668     gradient_fn=self.gradient_fn,
#     669     interface=self.interface,
#     670     gradient_kwargs=self.gradient_kwargs,
#     671     override_shots=override_shots,
#     672     **self.execute_kwargs,
#     673 )
#     675 if old_interface == "auto":
#     676     self.interface = "auto"
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/pennylane/interfaces/execution.py:718, in execute(tapes, device, gradient_fn, interface, mode, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform)
#     712 except ImportError as e:
#     713     raise qml.QuantumFunctionError(
#     714         f"{mapped_interface} not found. Please install the latest "
#     715         f"version of {mapped_interface} to enable the '{mapped_interface}' interface."
#     716     ) from e
# --> 718 res = _execute(
#     719     tapes, device, execute_fn, gradient_fn, gradient_kwargs, _n=1, max_diff=max_diff, mode=_mode
#     720 )
#     722 return batch_fn(res)
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/pennylane/interfaces/autograd.py:78, in execute(tapes, device, execute_fn, gradient_fn, gradient_kwargs, _n, max_diff, mode)
#      72 # pylint misidentifies autograd.builtins as a dict
#      73 # pylint: disable=no-member
#      74 parameters = autograd.builtins.tuple(
#      75     [autograd.builtins.list(t.get_parameters()) for t in tapes]
#      76 )
# ---> 78 return _execute(
#      79     parameters,
#      80     tapes=tapes,
#      81     device=device,
#      82     execute_fn=execute_fn,
#      83     gradient_fn=gradient_fn,
#      84     gradient_kwargs=gradient_kwargs,
#      85     _n=_n,
#      86     max_diff=max_diff,
#      87 )[0]
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/autograd/tracer.py:48, in primitive.<locals>.f_wrapped(*args, **kwargs)
#      46     return new_box(ans, trace, node)
#      47 else:
# ---> 48     return f_raw(*args, **kwargs)
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/pennylane/interfaces/autograd.py:122, in _execute(parameters, tapes, device, execute_fn, gradient_fn, gradient_kwargs, _n, max_diff)
#     101 """Autodifferentiable wrapper around ``Device.batch_execute``.
#     102
#     103 The signature of this function is designed to work around Autograd restrictions.
#    (...)
#     119 understand the consequences!
#     120 """
#     121 with qml.tape.Unwrap(*tapes):
# --> 122     res, jacs = execute_fn(tapes, **gradient_kwargs)
#     124 for i, r in enumerate(res):
#     125     if any(
#     126         m.return_type in (qml.measurements.Counts, qml.measurements.AllCounts)
#     127         for m in tapes[i].measurements
#     128     ):
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/pennylane/interfaces/execution.py:206, in cache_execute.<locals>.wrapper(tapes, **kwargs)
#     202         return (res, []) if return_tuple else res
#     204 else:
#     205     # execute all unique tapes that do not exist in the cache
# --> 206     res = fn(execution_tapes.values(), **kwargs)
#     208 final_res = []
#     210 for i, tape in enumerate(tapes):
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/pennylane/interfaces/execution.py:131, in cache_execute.<locals>.fn(tapes, **kwargs)
#     129 def fn(tapes: Sequence[QuantumTape], **kwargs):  # pylint: disable=function-redefined
#     130     tapes = [expand_fn(tape) for tape in tapes]
# --> 131     return original_fn(tapes, **kwargs)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/braket/pennylane_plugin/braket_device.py:491, in BraketAwsQubitDevice.batch_execute(self, circuits, **run_kwargs)
#     485 braket_circuits = [
#     486     self._pl_to_braket_circuit(circuit, **run_kwargs) for circuit in circuits
#     487 ]
#     489 batch_shots = 0 if self.analytic else self.shots
# --> 491 task_batch = self._device.run_batch(
#     492     braket_circuits,
#     493     s3_destination_folder=self._s3_folder,
#     494     shots=batch_shots,
#     495     max_parallel=self._max_parallel,
#     496     max_connections=self._max_connections,
#     497     poll_timeout_seconds=self._poll_timeout_seconds,
#     498     poll_interval_seconds=self._poll_interval_seconds,
#     499     **self._run_kwargs,
#     500 )
#     501 # Call results() to retrieve the Braket results in parallel.
#     502 try:
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/braket/aws/aws_device.py:246, in AwsDevice.run_batch(self, task_specifications, s3_destination_folder, shots, max_parallel, max_connections, poll_timeout_seconds, poll_interval_seconds, inputs, *aws_quantum_task_args, **aws_quantum_task_kwargs)
#     181 def run_batch(
#     182     self,
#     183     task_specifications: Union[
#    (...)
#     211     **aws_quantum_task_kwargs,
#     212 ) -> AwsQuantumTaskBatch:
#     213     """Executes a batch of tasks in parallel
#     214
#     215     Args:
#    (...)
#     244         `braket.aws.aws_quantum_task_batch.AwsQuantumTaskBatch`
#     245     """
# --> 246     return AwsQuantumTaskBatch(
#     247         AwsSession.copy_session(self._aws_session, max_connections=max_connections),
#     248         self._arn,
#     249         task_specifications,
#     250         s3_destination_folder
#     251         or (
#     252             AwsSession.parse_s3_uri(os.environ.get("AMZN_BRAKET_TASK_RESULTS_S3_URI"))
#     253             if "AMZN_BRAKET_TASK_RESULTS_S3_URI" in os.environ
#     254             else None
#     255         )
#     256         or (self._aws_session.default_bucket(), "tasks"),
#     257         shots if shots is not None else self._default_shots,
#     258         max_parallel=max_parallel if max_parallel is not None else self._default_max_parallel,
#     259         max_workers=max_connections,
#     260         poll_timeout_seconds=poll_timeout_seconds,
#     261         poll_interval_seconds=poll_interval_seconds,
#     262         inputs=inputs,
#     263         *aws_quantum_task_args,
#     264         **aws_quantum_task_kwargs,
#     265     )
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/braket/aws/aws_quantum_task_batch.py:97, in AwsQuantumTaskBatch.__init__(self, aws_session, device_arn, task_specifications, s3_destination_folder, shots, max_parallel, max_workers, poll_timeout_seconds, poll_interval_seconds, inputs, *aws_quantum_task_args, **aws_quantum_task_kwargs)
#      44 def __init__(
#      45     self,
#      46     aws_session: AwsSession,
#    (...)
#      64     **aws_quantum_task_kwargs,
#      65 ):
#      66     """Creates a batch of quantum tasks.
#      67
#      68     Args:
#    (...)
#      95             Default: {}.
#      96     """
# ---> 97     self._tasks = AwsQuantumTaskBatch._execute(
#      98         aws_session,
#      99         device_arn,
#     100         task_specifications,
#     101         s3_destination_folder,
#     102         shots,
#     103         max_parallel,
#     104         max_workers,
#     105         poll_timeout_seconds,
#     106         poll_interval_seconds,
#     107         inputs,
#     108         *aws_quantum_task_args,
#     109         **aws_quantum_task_kwargs,
#     110     )
#     111     self._aws_session = aws_session
#     112     self._results = None
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/braket/aws/aws_quantum_task_batch.py:238, in AwsQuantumTaskBatch._execute(aws_session, device_arn, task_specifications, s3_destination_folder, shots, max_parallel, max_workers, poll_timeout_seconds, poll_interval_seconds, inputs, *args, **kwargs)
#     235     remaining.clear()
#     237     raise
# --> 238 tasks = [future.result() for future in task_futures]
#     239 return tasks
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/braket/aws/aws_quantum_task_batch.py:238, in <listcomp>(.0)
#     235     remaining.clear()
#     237     raise
# --> 238 tasks = [future.result() for future in task_futures]
#     239 return tasks
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/concurrent/futures/_base.py:438, in Future.result(self, timeout)
#     436     raise CancelledError()
#     437 elif self._state == FINISHED:
# --> 438     return self.__get_result()
#     440 self._condition.wait(timeout)
#     442 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/concurrent/futures/_base.py:390, in Future.__get_result(self)
#     388 if self._exception:
#     389     try:
# --> 390         raise self._exception
#     391     finally:
#     392         # Break a reference cycle with the exception in self._exception
#     393         self = None
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/concurrent/futures/thread.py:52, in _WorkItem.run(self)
#      49     return
#      51 try:
# ---> 52     result = self.fn(*self.args, **self.kwargs)
#      53 except BaseException as exc:
#      54     self.future.set_exception(exc)
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/braket/aws/aws_quantum_task_batch.py:256, in AwsQuantumTaskBatch._create_task(remaining, aws_session, device_arn, task_specification, s3_destination_folder, shots, poll_interval_seconds, inputs, *args, **kwargs)
#     241 @staticmethod
#     242 def _create_task(
#     243     remaining: List[int],
#    (...)
#     254     **kwargs,
#     255 ) -> AwsQuantumTask:
# --> 256     task = AwsQuantumTask.create(
#     257         aws_session,
#     258         device_arn,
#     259         task_specification,
#     260         s3_destination_folder,
#     261         shots,
#     262         poll_interval_seconds=poll_interval_seconds,
#     263         inputs=inputs,
#     264         *args,
#     265         **kwargs,
#     266     )
#     268     remaining.pop()
#     270     # If the task hits a terminal state before all tasks have been created,
#     271     # it can be returned immediately
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/braket/aws/aws_quantum_task.py:182, in AwsQuantumTask.create(aws_session, device_arn, task_specification, s3_destination_folder, shots, device_parameters, disable_qubit_rewiring, tags, inputs, *args, **kwargs)
#     177     if unbounded_parameters:
#     178         raise ValueError(
#     179             f"Cannot execute circuit with unbound parameters: " f"{unbounded_parameters}"
#     180         )
# --> 182 return _create_internal(
#     183     task_specification,
#     184     aws_session,
#     185     create_task_kwargs,
#     186     device_arn,
#     187     device_parameters or {},
#     188     disable_qubit_rewiring,
#     189     inputs,
#     190     *args,
#     191     **kwargs,
#     192 )
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/functools.py:877, in singledispatch.<locals>.wrapper(*args, **kw)
#     873 if not args:
#     874     raise TypeError(f'{funcname} requires at least '
#     875                     '1 positional argument')
# --> 877 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/braket/aws/aws_quantum_task.py:600, in _(circuit, aws_session, create_task_kwargs, device_arn, device_parameters, disable_qubit_rewiring, inputs, *args, **kwargs)
#     589     openqasm_program = OpenQASMProgram(
#     590         source=openqasm_program.source,
#     591         inputs=inputs_copy,
#     592     )
#     594 create_task_kwargs.update(
#     595     {
#     596         "action": openqasm_program.json(),
#     597         "deviceParameters": device_parameters.json(),
#     598     }
#     599 )
# --> 600 task_arn = aws_session.create_quantum_task(**create_task_kwargs)
#     601 return AwsQuantumTask(task_arn, aws_session, *args, **kwargs)
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/braket/aws/aws_session.py:223, in AwsSession.create_quantum_task(self, **boto3_kwargs)
#     221 if job_token:
#     222     boto3_kwargs.update({"jobToken": job_token})
# --> 223 response = self.braket_client.create_quantum_task(**boto3_kwargs)
#     224 broadcast_event(
#     225     _TaskCreationEvent(
#     226         arn=response["quantumTaskArn"],
#    (...)
#     230     )
#     231 )
#     232 return response["quantumTaskArn"]
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/botocore/client.py:530, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     526     raise TypeError(
#     527         f"{py_operation_name}() only accepts keyword arguments."
#     528     )
#     529 # The "self" in this scope is referring to the BaseClient.
# --> 530 return self._make_api_call(operation_name, kwargs)
#
# File ~/Repositories/qhack23_rydberg_graph/venv/lib/python3.9/site-packages/botocore/client.py:960, in BaseClient._make_api_call(self, operation_name, api_params)
#     958     error_code = parsed_response.get("Error", {}).get("Code")
#     959     error_class = self.exceptions.from_code(error_code)
# --> 960     raise error_class(parsed_response, operation_name)
#     961 else:
#     962     return parsed_response
#
# ClientError: An error occurred (InternalServerErrorException) when calling the CreateQuantumTask operation (reached max retries: 4): Endpoint request timed out
# time: 44min 7s (started: 2023-02-28 13:26:05 -05:00)

# %%
filename = 'demo_results_pennylane_sv1.p'

if not os.path.isdir('results_QEK/'):
    os.mkdir('results_QEK/')
with open("results_QEK/"+filename, 'wb') as f:
    f.write(pickle.dumps(results))

# %%
new_results = [[_convert_to_counts(result_graph, n_wires) for result_graph in results_graph]for results_graph in results]

# %%
new_results[0][0]

# %%
kernel_counts_fn = partial(outcome_counts, shots=shots)
kernels = []
for t_max, counts_graph in zip(t_range, new_results): # loop over different drive durations
    # counts_graph = [get_counts(result_graph) for result_graph in results_graph] # get state counts from simulator result
    # counts_graph = [get_counts(result) for result in results] # get state counts from simulator result
    kernel_t = compute_kernel(counts_graph, kernel_counts_fn) # compute kernel matrix
    kernels.append(kernel_t)
kernels = np.stack(kernels)

# %%
fig, axes = plt.subplots(1, 1, figsize=(12, 7))
axes.plot(t_range, (- np.log(kernels[:, 0, 1]))**2, label='kernel')
axes.set_xlabel('t')
axes.set_ylabel(r'Jensen-Shannon divergence $JS(P1, P2)$')

# %%
outcome_fn = partial(get_expectations_nodes, shots=shots, averaged_nodes=my_nodesB)
outcomes = []
for t_max, counts_graph in zip(t_range, new_results): # loop over different drive durations
    # counts_graph = [get_counts(result_graph) for result_graph in results_graph] # get state counts from simulator result
    outcomes_t = compute_outcomes(counts_graph, outcome_fn) # compute kernel matrix
    # print(outcomes_t.shape)
    outcomes.append(outcomes_t)
outcomes = np.stack(outcomes)

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 7), sharex=True)
y_labels = [r'$\langle n_B \rangle$', r'$\langle n_C \rangle$']
labels = ['B', 'C']
colors = ['r', 'b']
labels_graph = ['A', 'B']
for i, ylabel in enumerate(y_labels):
    ax = axes[i]
    for j in range(2):
        ax.plot(t_range, outcomes[:, j, i], '.-', label=f"graph {labels_graph[j]}", color=colors[j])
    ax.set_ylabel(ylabel)
    ax.legend()

plt.xlabel('Drive duration [s]')
# plt.legend()
# plt.ylabel(r'$\langle n \rangle$')

# %%
t_list = [0.1e-6, 0.25e-6, 0.57e-6, 0.924e-6, 1.04e-6, 1.2e-6, 2.5e-6]
barWidth = 0.25
br1 = np.arange(len(graphA_nodes)+1)
br2 = [x + barWidth for x in br1]
bars = [br1, br2]
colors = ['r', 'b']
labels = ['graph A', 'graph B']
# plot the probability distribution for different drive durations as a function of summed states
fig, axes = plt.subplots(len(t_list), 1, figsize=(5, 4 * len(t_list)), sharex=True)
for t, ax in zip(t_list, axes):
    # idx = np.where(t_range == t)[0][0] # get index of t
    idx = np.argmin(np.abs(t_range - t))
    probabilities = []
    
    for i in range(2):
        counts_graph = new_results[idx][i]
        p = get_counts_summed_probabilities(counts_graph, shots=shots)
        probabilities.append(p)
        # print(p)

        ax.bar(bars[i], p, label=labels[i], width=barWidth, color=colors[i])
        # ax.set_ylim(0, 1)
        ax.set_ylabel("Probability")
        ax.set_xlabel(r"Summed states $\sum_i n_i$")
        ax.legend()
        ax.set_title('t = {:.2e}'.format(t_range[idx]))
    # ax.set_title('t = {:.2e}'.format(t))
